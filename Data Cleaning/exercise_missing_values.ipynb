# %%
# !pip install opendatasets
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\bivan\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73053 sha256=aa1d427f7d0ede0d8aec4ad2d863894480068eb5db2aa781cc7ef5b4738c26c7
#   Stored in directory: c:\users\bivan\appdata\local\pip\cache\wheels\ac\b2\c3\fa4706d469b5879105991d1c8be9a3c2ef329ba9fe2ce5085e
# Successfully built kaggle
# ...

# %%
import opendatasets as od
# modules we'll use
import pandas as pd
import numpy as np
import os

# %%
dataset = 'https://www.kaggle.com/datasets/aparnashastry/building-permit-applications-data'
od.download(dataset)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 18.0M/18.0M [00:09<00:00, 2.04MB/s]

# %%
os.listdir(r'.\building-permit-applications-data')
# Out:
# ['Building_Permits.csv', 'DataDictionaryBuildingPermit.xlsx']

# %%
sf_permits = pd.read_csv(r'.\building-permit-applications-data\Building_Permits.csv')
sf_permits

# set seed for reproducibility
np.random.seed(0)
# Out:
# c:\users\bivan\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#Q1. Use the code cell below to print the first five rows of the sf_permits DataFrame.

sf_permits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
#Q2. Does the dataset have any missing values? Once you have an answer, run the code cell below to get credit for your work.

#The first five rows of the data does show that several columns have missing values. Like "Street Number Suffix", "Proposed Construction Type" and "Site Permit" columns, among others.
# Out:
#   File "<ipython-input-21-b439ac29d247>", line 1
#     Q2. Does the dataset have any missing values? Once you have an answer, run the code cell below to get credit for your work.
#              ^
# SyntaxError: invalid syntax

# %%
#Q3. How many missing data points do we have?

missing_values_count = sf_permits.isnull().sum()

total_cells = np.product(sf_permits.shape)
total_missing = missing_values_count.sum()

percent_missing = (total_missing/total_cells)*100
print(percent_missing)
# Out:
# 26.26002315058403

# %%
missing_values_count[:]
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
#Q4. Drop missing values: rows
    
row_dropna = sf_permits.dropna()
print("Rows in original dataset: %d \n" % sf_permits.shape[0])
print("Rows with na's dropped: %d" % row_dropna.shape[0])
# Out:
# Rows in original dataset: 198900
#
# Rows with na's dropped: 0

# %%
#Q5. 5) Drop missing values: columns

col_dropna = sf_permits.dropna(axis=1)
print("Columns in original dataset: %d \n" % sf_permits.shape[1])
print("Columns with na's dropped: %d" % col_dropna.shape[1])
# Out:
# Columns in original dataset: 43
#
# Columns with na's dropped: 12

# %%
#Q6. 6) Fill in missing values automatically

sf_permits_with_na_imputed = sf_permits.fillna(method='bfill', axis=0).fillna(0)
sf_permits_with_na_imputed.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                    A
# 1           04/19/2016  0306  007            440                    A
# 2           05/27/2016  0595  203           1647                    A
# 3           11/07/2016  0156  011           1230                    A
# 4           11/28/2016  0342  001            950                    A
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...
